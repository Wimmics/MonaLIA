# %% [markdown]
# http://www.dreambank.net/regex.html

# %%
import pandas as pd
import zipfile as zf

import os

# %%
root_dir = 'c:\Kaggle'


all_data_info = pd.read_csv('C:\\datasets\\Kaggle\\zip\\all_data_info.csv\\all_data_info.csv')

print(all_data_info.shape)
all_data_info.head(20)
# Out:
# (103250, 12)
#                        artist    date                     genre  pixelsx  \
# 0              Barnett Newman  1955.0                  abstract  15530.0
# 1              Barnett Newman  1950.0                  abstract  14559.0
# 2                 kiri nichol  2013.0                       NaN   9003.0
# 3                 kiri nichol  2013.0                       NaN   9003.0
# 4                 kiri nichol  2013.0                       NaN   9003.0
# 5               Tosa Mitsuoki     NaN     mythological painting  25528.0
# 6              Barnett Newman     NaN                  abstract   7345.0
# 7                   Hiroshige    1838  bird-and-flower painting   6483.0
# 8              Barnett Newman  1963.0                  abstract   6049.0
# 9   Franz Richard Unterberger     NaN                 cityscape   6238.0
# 10                  Hiroshige    1844  bird-and-flower painting   5492.0
# 11            Wolfgang Paalen  1937.0                 landscape   5331.0
# ...

# %%
all_data_info.title.fillna('', inplace=True)
all_data_info.title = all_data_info.title.str.lower()

# %%
cat = r'\b(cat|kitten|kitty|kittie|feline)s?\b'

dog = r'\b(dog|puppy|puppie|canine)s?\b'

sword = r'\b(sword|foil|blade|epee|rapier|espadron)s?\b'

df = all_data_info[all_data_info.title.str.contains(sword)]

print(df.shape)
df
# Out:
# (32, 12)
#                                artist    date                  genre  pixelsx  \
# 477               Konstantin Vasilyev     NaN  mythological painting   2834.0
# 661                Katsushika Hokusai     NaN         genre painting   4054.0
# 3796                Utagawa Kuniyoshi     NaN        battle painting   2800.0
# 5005                Utagawa Kuniyoshi     NaN        battle painting   1790.0
# 5697                 Bernhard Strigel     NaN         genre painting   2024.0
# 8901                       N.C. Wyeth    1922           illustration   1590.0
# 9957                    Edouard Manet    1861               portrait   1434.0
# 13252                Nicholas Roerich     NaN  mythological painting   1800.0
# 13605                Nicholas Roerich    1932  mythological painting   1800.0
# 13677                     Franz Stuck    1889     religious painting   1256.0
# 15917                    Jean Fouquet    1460       history painting   1122.0
# ...

# %%
count = 0
with zf.ZipFile('C:/Datasets/Kaggle/test.zip', 'r') as myzip:
    for fn in cat_df.new_filename:
        file_name = 'test/%s' % fn
        try:
            if not os.path.isfile(os.path.join('C:/Datasets/Kaggle/train/chat', fn)):
                
                myzip.extract( fn, 'C:/Datasets/Kaggle/train/chat/new')
                print('%s extracted' % os.path.join('C:/Datasets/Kaggle/train/chat', fn))
                count += 1
            else:
                print('%s exists' % os.path.join('C:/Datasets/Kaggle/train/chat', fn))
        
        except Exception as e: 
            print('%s not extracted. Error: %s' % (fn,e))
        
print(count)
# Out:
# C:/Datasets/Kaggle/train/chat\101495.jpg exists
# C:/Datasets/Kaggle/train/chat\3205.jpg exists
# C:/Datasets/Kaggle/train/chat\6968.jpg exists
# C:/Datasets/Kaggle/train/chat\65894.jpg exists
# C:/Datasets/Kaggle/train/chat\14390.jpg exists
# C:/Datasets/Kaggle/train/chat\47385.jpg exists
# C:/Datasets/Kaggle/train/chat\49837.jpg exists
# C:/Datasets/Kaggle/train/chat\35599.jpg exists
# C:/Datasets/Kaggle/train/chat\81822.jpg exists
# C:/Datasets/Kaggle/train/chat\18556.jpg exists
# C:/Datasets/Kaggle/train/chat\74734.jpg exists
# C:/Datasets/Kaggle/train/chat\21961.jpg exists
# C:/Datasets/Kaggle/train/chat\60635.jpg exists
# C:/Datasets/Kaggle/train/chat\101166.jpg exists
# C:/Datasets/Kaggle/train/chat\101714.jpg exists
# C:/Datasets/Kaggle/train/chat\3682.jpg exists
# C:/Datasets/Kaggle/train/chat\60230.jpg exists
# C:/Datasets/Kaggle/train/chat\62437.jpg exists
# C:/Datasets/Kaggle/train/chat\28006.jpg exists
# C:/Datasets/Kaggle/train/chat\55091.jpg exists
# ...
